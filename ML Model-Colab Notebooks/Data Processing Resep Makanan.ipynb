# %% [markdown]
# # Proses Ambil dataset dari drive

# %%
# Data wrangling and math
import numpy as np
import pandas as pd 

# Visualization tools
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
#Ambil csv dari drive
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd 
df_ayam=pd.read_csv('gdrive/My Drive/resepmakanan/dataset-ayam.csv')

# %%
#Baca file CSV di drive
df_ayam=pd.read_csv('gdrive/My Drive/resepmakanan/dataset-ayam.csv')
df_ikan=pd.read_csv('gdrive/My Drive/resepmakanan/dataset-ikan.csv')
df_sapi=pd.read_csv('gdrive/My Drive/resepmakanan/dataset-sapi.csv')
df_kambing=pd.read_csv('gdrive/My Drive/resepmakanan/dataset-kambing.csv')

# %%
#Melihat urutan makanan paling disukai
loved_food = df_kambing.sort_values(by='Loves', ascending=False)[:10]
figure = plt.figure(figsize=(10,6))
sns.barplot(y=loved_food.Title, x=loved_food.Loves)
plt.xticks()
plt.xlabel('Food recipe')
plt.ylabel('Loves count')
plt.title('The Most Loved Food Recipe')
plt.show()

# %% [markdown]
# # Scaling dataset pada rating menggunakan minmaxscaler
# Dataset yang besar, dan memiliki range yang tinggi akan menyulitkan algoritma dalam melakukan tugasnya (membuat rekomendasi). Dengan penggunaan MinMaxScaler dari sklearn, akan memudahkan dalam melakukan pemrosesan data. Kolom yang akan discaling adalah kolom rating.

# %%
#sortir yang paling disukai
'''
from sklearn.preprocessing import MinMaxScaler
minmax_scaler = MinMaxScaler()
df_kambing[["Loves"]] = minmax_scaler.fit_transform(df_kambing[["Loves"]])
'''
df_sapi.sort_values('Loves',ascending=False)
# Out:
#                                                 Title  \
# 1747                       Bakso Sapi (Pakai Blender)
# 1487                    Sop Iga Sapi Enaaak bangeet👌👍
# 111                                 Lapis daging sapi
# 1851  Bakso Sapi Homemade (bs daging frozen bs fresh)
# 300                        Nasi Kebuli Sapi Magic com
# ...                                               ...
# 1738                           Pasta Tutup Sosis Sapi
# 145                                      Beef Lasagna
# 784                                         [Notitle]
# 678                         Dendeng Balado Sapi Pedas
# 0                                       Beef Teriyaki
#
#                                             Ingredients  \
# 1747  250 gram daging sapi--35 gram es batu (sekitar...
# 1487  1 kg iga sapi, cuci bersih, tiriskan--Secukupn...
# 111   750 daging sapi (khas dalam)--3 lembar daun sa...
# 1851  250 gr daging sapi (potong kecil")--6 siung ba...
# ...

# %% [markdown]
# # Menggabungkan File CSV menjadi 1 file

# %%
#Gabungkan berberapa file csv menjadi 1 file
df = df_ayam.append([df_ikan,df_kambing,df_sapi])

'''
#Convert ke dalam bentuk file csv dan save di drive
df.to_csv('gdrive/My Drive/resepmakanan/dataset-gabung.csv')
data_baru= pd.read_csv('gdrive/My Drive/resepmakanan/dataset-gabung.csv')
data_baru
'''
df
# Out:
# <ipython-input-6-5f1db2445101>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df_ayam.append([df_ikan,df_kambing,df_sapi])
#                                                   Title  \
# 0                                      Ayam Woku Manado
# 1                              Ayam goreng tulang lunak
# 2                                      Ayam cabai kawin
# 3                                           Ayam Geprek
# 4                                           Minyak Ayam
# ...                                                 ...
# 1953  Bistik sapi empuk. Dengan tips memasak daging ...
# 1954                               Tongseng Daging Sapi
# 1955                               Sayur godog Iga sapi
# 1956                                    Sup daging sapi
# 1957                   Sop sayur tetelan daging sapi 🐄🐮
#
#                                             Ingredients  \
# ...

# %% [markdown]
# # Menghapus Kolom yang tidak dibutuhkan

# %%
df.drop(['Steps',
       'URL'],1,inplace=True)
df
# Out:
# <ipython-input-8-d217ea9ca97a>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(['Steps',
#                                                   Title  \
# 0                                      Ayam Woku Manado
# 1                              Ayam goreng tulang lunak
# 2                                      Ayam cabai kawin
# 3                                           Ayam Geprek
# 4                                           Minyak Ayam
# ...                                                 ...
# 1953  Bistik sapi empuk. Dengan tips memasak daging ...
# 1954                               Tongseng Daging Sapi
# 1955                               Sayur godog Iga sapi
# 1956                                    Sup daging sapi
# 1957                   Sop sayur tetelan daging sapi 🐄🐮
#
#                                             Ingredients  Loves
# ...

# %%
#ganti kata di fie dan menghapus kata yang tidak diperlukan
# Replacing "United Kingdom with "UK"
df.Title = df.Title.str.replace('empuk', '')
df
# Out:
#                                                 Title  \
# 0                                    Ayam Woku Manado
# 1                            Ayam goreng tulang lunak
# 2                                    Ayam cabai kawin
# 3                                         Ayam Geprek
# 4                                         Minyak Ayam
# ...                                               ...
# 1953  Bistik sapi . Dengan tips memasak daging agar
# 1954                             Tongseng Daging Sapi
# 1955                             Sayur godog Iga sapi
# 1956                                  Sup daging sapi
# 1957                 Sop sayur tetelan daging sapi 🐄🐮
#
#                                             Ingredients  Loves
# 0     1 Ekor Ayam Kampung (potong 12)--2 Buah Jeruk ...      1
# 1     1 kg ayam (dipotong sesuai selera jangan kecil...      1
# 2     1/4 kg ayam--3 buah cabai hijau besar--7 buah ...      2
# 3     250 gr daging ayam (saya pakai fillet)--Secuku...     10
# ...
